# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv",index_col = 0)

# %%
matches.head()
# Out:
#          date   time     comp        round  day venue result   gf   ga  \
# 0  2023-08-12  21:30  La Liga  Matchweek 1  Sat  Away      W  2.0  0.0
# 1  2023-08-19  19:30  La Liga  Matchweek 2  Sat  Away      W  3.0  1.0
# 2  2023-08-25  21:30  La Liga  Matchweek 3  Fri  Away      W  1.0  0.0
# 3  2023-09-02  16:15  La Liga  Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2023-09-17  21:00  La Liga  Matchweek 5  Sun  Home      W  2.0  1.0
#
#         opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0  Athletic Club  ...  Match Report    NaN  14.0   8.0  16.0  2.0  0     0
# 1        Almería  ...  Match Report    NaN  25.0   9.0  17.0  1.0  0     0
# 2     Celta Vigo  ...  Match Report    NaN   9.0   2.0  19.4  0.0  0     1
# 3         Getafe  ...  Match Report    NaN  26.0  12.0  17.7  0.0  0     0
# 4  Real Sociedad  ...  Match Report    NaN  17.0   8.0  15.9  1.0  0     0
#
#   season         team
# 0   2024  Real Madrid
# 1   2024  Real Madrid
# 2   2024  Real Madrid
# 3   2024  Real Madrid
# 4   2024  Real Madrid
#
# [5 rows x 28 columns]

# %%
matches.shape
# Out:
# (8550, 28)

# %%
matches["team"].value_counts()
# Out:
# team
# Real Madrid            494
# Barcelona              456
# Atletico Madrid        456
# Athletic Club          418
# Real Sociedad          418
# Celta Vigo             418
# Real Betis             418
# Villarreal             418
# Valencia               418
# Getafe                 418
# Sevilla                418
# Alaves                 380
# Girona                 342
# Osasuna                342
# Mallorca               304
# Rayo Vallecano         304
# Cadiz                  304
# Granada                304
# Las Palmas             228
# Almeria                228
# Espanyol               190
# Levante                190
# Valladolid             152
# Eibar                  152
# Elche                  114
# Leganes                114
# Huesca                  76
# Deportivo La Coruna     38
# Malaga                  38
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Barcelona"]
# Out:
#           date   time     comp         round  day venue result   gf   ga  \
# 0   2023-08-13  21:30  La Liga   Matchweek 1  Sun  Away      D  0.0  0.0
# 1   2023-08-20  19:30  La Liga   Matchweek 2  Sun  Home      W  2.0  0.0
# 2   2023-08-27  17:30  La Liga   Matchweek 3  Sun  Away      W  4.0  3.0
# 3   2023-09-03  21:00  La Liga   Matchweek 4  Sun  Away      W  2.0  1.0
# 4   2023-09-16  21:00  La Liga   Matchweek 5  Sat  Home      W  5.0  0.0
# ..         ...    ...      ...           ...  ...   ...    ...  ...  ...
# 54  2018-04-29  20:45  La Liga  Matchweek 35  Sun  Away      W  4.0  2.0
# 55  2018-05-06  20:45  La Liga  Matchweek 36  Sun  Home      D  2.0  2.0
# 56  2018-05-09  20:00  La Liga  Matchweek 34  Wed  Home      W  5.0  1.0
# 57  2018-05-13  20:45  La Liga  Matchweek 37  Sun  Away      L  4.0  5.0
# 58  2018-05-20  20:45  La Liga  Matchweek 38  Sun  Home      W  1.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0          Getafe  ...  Match Report    NaN  14.0   3.0  19.9  1.0  0     0
# 1           Cádiz  ...  Match Report    NaN  24.0  10.0  15.5  2.0  0     0
# 2      Villarreal  ...  Match Report    NaN  21.0  11.0  16.8  0.0  0     0
# 3         Osasuna  ...  Match Report    NaN   8.0   3.0  15.6  0.0  1     1
# 4           Betis  ...  Match Report    NaN  17.0   9.0  18.7  2.0  0     0
# ..            ...  ...           ...    ...   ...   ...   ...  ... ..   ...
# 54      La Coruña  ...  Match Report    NaN  21.0   9.0  15.3  1.0  0     0
# 55    Real Madrid  ...  Match Report    NaN  11.0   4.0  15.1  1.0  0     0
# 56     Villarreal  ...  Match Report    NaN  12.0   6.0  16.0  0.0  0     0
# 57        Levante  ...  Match Report    NaN  17.0   6.0  17.8  1.0  1     1
# 58  Real Sociedad  ...  Match Report    NaN  12.0   4.0  17.2  1.0  0     0
#
#    season       team
# 0    2024  Barcelona
# 1    2024  Barcelona
# 2    2024  Barcelona
# 3    2024  Barcelona
# 4    2024  Barcelona
# ..    ...        ...
# 54   2023  Barcelona
# 55   2023  Barcelona
# 56   2023  Barcelona
# 57   2023  Barcelona
# 58   2023  Barcelona
#
# [456 rows x 28 columns]

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     225
# Matchweek 2     225
# Matchweek 3     225
# Matchweek 4     225
# Matchweek 5     225
# Matchweek 6     225
# Matchweek 7     225
# Matchweek 8     225
# Matchweek 9     225
# Matchweek 10    225
# Matchweek 11    225
# Matchweek 12    225
# Matchweek 13    225
# Matchweek 14    225
# Matchweek 15    225
# Matchweek 16    225
# Matchweek 17    225
# Matchweek 18    225
# Matchweek 19    225
# Matchweek 21    225
# Matchweek 22    225
# Matchweek 20    225
# Matchweek 23    225
# Matchweek 24    225
# Matchweek 25    225
# Matchweek 26    225
# Matchweek 27    225
# Matchweek 28    225
# Matchweek 29    225
# Matchweek 30    225
# Matchweek 31    225
# Matchweek 32    225
# Matchweek 33    225
# Matchweek 34    225
# Matchweek 35    225
# Matchweek 36    225
# Matchweek 37    225
# Matchweek 38    225
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf               float64
# ga               float64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
#need to convert all data-type to numeric either float or int since ml can only work with that data

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
#converts date to the pandas datetime datatype

# %%
matches
# Out:
#          date   time     comp         round  day venue result   gf   ga  \
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W  2.0  0.0
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W  3.0  1.0
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W  1.0  0.0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W  2.0  1.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 35 2018-04-22  16:15  La Liga  Matchweek 34  Sun  Home      W  2.0  0.0
# 36 2018-04-30  21:00  La Liga  Matchweek 35  Mon  Away      L  1.0  2.0
# 37 2018-05-06  12:00  La Liga  Matchweek 36  Sun  Home      L  0.0  3.0
# 38 2018-05-13  16:15  La Liga  Matchweek 37  Sun  Away      L  1.0  4.0
# 39 2018-05-19  18:30  La Liga  Matchweek 38  Sat  Home      L  0.0  1.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk pk pkatt  \
# 0   Athletic Club  ...  Match Report    NaN  14.0   8.0  16.0  2.0  0     0
# 1         Almería  ...  Match Report    NaN  25.0   9.0  17.0  1.0  0     0
# 2      Celta Vigo  ...  Match Report    NaN   9.0   2.0  19.4  0.0  0     1
# 3          Getafe  ...  Match Report    NaN  26.0  12.0  17.7  0.0  0     0
# 4   Real Sociedad  ...  Match Report    NaN  17.0   8.0  15.9  1.0  0     0
# ..            ...  ...           ...    ...   ...   ...   ...  ... ..   ...
# 35  Real Sociedad  ...  Match Report    NaN   5.0   4.0  11.5  0.0  0     0
# 36          Betis  ...  Match Report    NaN   9.0   3.0  16.7  0.0  0     0
# 37         Alavés  ...  Match Report    NaN  16.0   4.0  15.4  1.0  0     0
# 38       Espanyol  ...  Match Report    NaN   8.0   2.0  17.3  0.0  1     1
# 39         Getafe  ...  Match Report    NaN   6.0   2.0  12.9  0.0  0     0
#
#    season         team
# 0    2024  Real Madrid
# 1    2024  Real Madrid
# 2    2024  Real Madrid
# 3    2024  Real Madrid
# 4    2024  Real Madrid
# ..    ...          ...
# 35   2023       Malaga
# 36   2023       Malaga
# 37   2023       Malaga
# 38   2023       Malaga
# 39   2023       Malaga
#
# [8550 rows x 28 columns]

# %%
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                      float64
# ga                      float64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                      float64
# sot                     float64
# dist                    float64
# fk                      float64
# pk                        int64
# pkatt                     int64
# season                    int64
# team                     object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
#venue_code stores either a 0 to signify the team is away and a 1 to show the team is home

# %%
matches
# Out:
#          date   time     comp         round  day venue result   gf   ga  \
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W  2.0  0.0
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W  3.0  1.0
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W  1.0  0.0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W  2.0  1.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 35 2018-04-22  16:15  La Liga  Matchweek 34  Sun  Home      W  2.0  0.0
# 36 2018-04-30  21:00  La Liga  Matchweek 35  Mon  Away      L  1.0  2.0
# 37 2018-05-06  12:00  La Liga  Matchweek 36  Sun  Home      L  0.0  3.0
# 38 2018-05-13  16:15  La Liga  Matchweek 37  Sun  Away      L  1.0  4.0
# 39 2018-05-19  18:30  La Liga  Matchweek 38  Sat  Home      L  0.0  1.0
#
#          opponent  ...  notes    sh   sot  dist   fk pk pkatt season  \
# 0   Athletic Club  ...    NaN  14.0   8.0  16.0  2.0  0     0   2024
# 1         Almería  ...    NaN  25.0   9.0  17.0  1.0  0     0   2024
# 2      Celta Vigo  ...    NaN   9.0   2.0  19.4  0.0  0     1   2024
# 3          Getafe  ...    NaN  26.0  12.0  17.7  0.0  0     0   2024
# 4   Real Sociedad  ...    NaN  17.0   8.0  15.9  1.0  0     0   2024
# ..            ...  ...    ...   ...   ...   ...  ... ..   ...    ...
# 35  Real Sociedad  ...    NaN   5.0   4.0  11.5  0.0  0     0   2023
# 36          Betis  ...    NaN   9.0   3.0  16.7  0.0  0     0   2023
# 37         Alavés  ...    NaN  16.0   4.0  15.4  1.0  0     0   2023
# 38       Espanyol  ...    NaN   8.0   2.0  17.3  0.0  1     1   2023
# 39         Getafe  ...    NaN   6.0   2.0  12.9  0.0  0     0   2023
#
#            team  venue_code
# 0   Real Madrid           0
# 1   Real Madrid           0
# 2   Real Madrid           0
# 3   Real Madrid           1
# 4   Real Madrid           1
# ..          ...         ...
# 35       Malaga           1
# 36       Malaga           0
# 37       Malaga           1
# 38       Malaga           0
# 39       Malaga           1
#
# [8550 rows x 29 columns]

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
#opponent_code stores a numeric value based on the opponent

# %%
matches
# Out:
#          date   time     comp         round  day venue result   gf   ga  \
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W  2.0  0.0
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W  3.0  1.0
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W  1.0  0.0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W  2.0  1.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 35 2018-04-22  16:15  La Liga  Matchweek 34  Sun  Home      W  2.0  0.0
# 36 2018-04-30  21:00  La Liga  Matchweek 35  Mon  Away      L  1.0  2.0
# 37 2018-05-06  12:00  La Liga  Matchweek 36  Sun  Home      L  0.0  3.0
# 38 2018-05-13  16:15  La Liga  Matchweek 37  Sun  Away      L  1.0  4.0
# 39 2018-05-19  18:30  La Liga  Matchweek 38  Sat  Home      L  0.0  1.0
#
#          opponent  ...    sh   sot  dist   fk pk pkatt season         team  \
# 0   Athletic Club  ...  14.0   8.0  16.0  2.0  0     0   2024  Real Madrid
# 1         Almería  ...  25.0   9.0  17.0  1.0  0     0   2024  Real Madrid
# 2      Celta Vigo  ...   9.0   2.0  19.4  0.0  0     1   2024  Real Madrid
# 3          Getafe  ...  26.0  12.0  17.7  0.0  0     0   2024  Real Madrid
# 4   Real Sociedad  ...  17.0   8.0  15.9  1.0  0     0   2024  Real Madrid
# ..            ...  ...   ...   ...   ...  ... ..   ...    ...          ...
# 35  Real Sociedad  ...   5.0   4.0  11.5  0.0  0     0   2023       Malaga
# 36          Betis  ...   9.0   3.0  16.7  0.0  0     0   2023       Malaga
# 37         Alavés  ...  16.0   4.0  15.4  1.0  0     0   2023       Malaga
# 38       Espanyol  ...   8.0   2.0  17.3  0.0  1     1   2023       Malaga
# 39         Getafe  ...   6.0   2.0  12.9  0.0  0     0   2023       Malaga
#
#    venue_code  opp_code
# 0           0         2
# 1           0         1
# 2           0         6
# 3           1        11
# 4           1        24
# ..        ...       ...
# 35          1        24
# 36          0         5
# 37          1         0
# 38          0        10
# 39          1        11
#
# [8550 rows x 30 columns]

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex = True).astype("int")

# %%
#gets a time column that is only the hour

# %%
matches
# Out:
#          date   time     comp         round  day venue result   gf   ga  \
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W  2.0  0.0
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W  3.0  1.0
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W  1.0  0.0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W  2.0  1.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 35 2018-04-22  16:15  La Liga  Matchweek 34  Sun  Home      W  2.0  0.0
# 36 2018-04-30  21:00  La Liga  Matchweek 35  Mon  Away      L  1.0  2.0
# 37 2018-05-06  12:00  La Liga  Matchweek 36  Sun  Home      L  0.0  3.0
# 38 2018-05-13  16:15  La Liga  Matchweek 37  Sun  Away      L  1.0  4.0
# 39 2018-05-19  18:30  La Liga  Matchweek 38  Sat  Home      L  0.0  1.0
#
#          opponent  ...   sot  dist   fk  pk pkatt season         team  \
# 0   Athletic Club  ...   8.0  16.0  2.0   0     0   2024  Real Madrid
# 1         Almería  ...   9.0  17.0  1.0   0     0   2024  Real Madrid
# 2      Celta Vigo  ...   2.0  19.4  0.0   0     1   2024  Real Madrid
# 3          Getafe  ...  12.0  17.7  0.0   0     0   2024  Real Madrid
# 4   Real Sociedad  ...   8.0  15.9  1.0   0     0   2024  Real Madrid
# ..            ...  ...   ...   ...  ...  ..   ...    ...          ...
# 35  Real Sociedad  ...   4.0  11.5  0.0   0     0   2023       Malaga
# 36          Betis  ...   3.0  16.7  0.0   0     0   2023       Malaga
# 37         Alavés  ...   4.0  15.4  1.0   0     0   2023       Malaga
# 38       Espanyol  ...   2.0  17.3  0.0   1     1   2023       Malaga
# 39         Getafe  ...   2.0  12.9  0.0   0     0   2023       Malaga
#
#    venue_code opp_code  hour
# 0           0        2    21
# 1           0        1    19
# 2           0        6    21
# 3           1       11    16
# 4           1       24    21
# ..        ...      ...   ...
# 35          1       24    16
# 36          0        5    21
# 37          1        0    12
# 38          0       10    16
# 39          1       11    18
#
# [8550 rows x 31 columns]

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
#gets the day of the week as a number

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
#(matches["result"] == "W") returns a boolean whether it is a W
#then it gets stored as an int, 1 for true, 0 for false

# %%
matches
# Out:
#          date   time     comp         round  day venue result   gf   ga  \
# 0  2023-08-12  21:30  La Liga   Matchweek 1  Sat  Away      W  2.0  0.0
# 1  2023-08-19  19:30  La Liga   Matchweek 2  Sat  Away      W  3.0  1.0
# 2  2023-08-25  21:30  La Liga   Matchweek 3  Fri  Away      W  1.0  0.0
# 3  2023-09-02  16:15  La Liga   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2023-09-17  21:00  La Liga   Matchweek 5  Sun  Home      W  2.0  1.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 35 2018-04-22  16:15  La Liga  Matchweek 34  Sun  Home      W  2.0  0.0
# 36 2018-04-30  21:00  La Liga  Matchweek 35  Mon  Away      L  1.0  2.0
# 37 2018-05-06  12:00  La Liga  Matchweek 36  Sun  Home      L  0.0  3.0
# 38 2018-05-13  16:15  La Liga  Matchweek 37  Sun  Away      L  1.0  4.0
# 39 2018-05-19  18:30  La Liga  Matchweek 38  Sat  Home      L  0.0  1.0
#
#          opponent  ...   fk  pk  pkatt  season         team venue_code  \
# 0   Athletic Club  ...  2.0   0      0    2024  Real Madrid          0
# 1         Almería  ...  1.0   0      0    2024  Real Madrid          0
# 2      Celta Vigo  ...  0.0   0      1    2024  Real Madrid          0
# 3          Getafe  ...  0.0   0      0    2024  Real Madrid          1
# 4   Real Sociedad  ...  1.0   0      0    2024  Real Madrid          1
# ..            ...  ...  ...  ..    ...     ...          ...        ...
# 35  Real Sociedad  ...  0.0   0      0    2023       Malaga          1
# 36          Betis  ...  0.0   0      0    2023       Malaga          0
# 37         Alavés  ...  1.0   0      0    2023       Malaga          1
# 38       Espanyol  ...  0.0   1      1    2023       Malaga          0
# 39         Getafe  ...  0.0   0      0    2023       Malaga          1
#
#    opp_code hour day_code  target
# 0         2   21        5       1
# 1         1   19        5       1
# 2         6   21        4       1
# 3        11   16        5       1
# 4        24   21        6       1
# ..      ...  ...      ...     ...
# 35       24   16        6       1
# 36        5   21        0       0
# 37        0   12        6       0
# 38       10   16        6       0
# 39       11   18        5       0
#
# [8550 rows x 33 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 101, min_samples_split = 150, random_state = 1)

# %%
train = matches[matches["date"] < '2023-01-01']

# %%
test = matches[matches["date"] >= '2023-01-01']

# %%
predictors = ["venue_code", "opp_code",  "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=150, n_estimators=101, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6514606741573034

# %%
combined = pd.DataFrame(dict(actual = test["target"], prediction = preds), index = test.index)

# %%
pd.crosstab(index = combined["actual"], columns = combined["prediction"])
# Out:
# prediction     0    1
# actual
# 0           2465  308
# 1           1243  434

# %%
#0 represents loss or draw, therefore, 2165 we were correct, 1141 we were wrong

# %%
#1 represents wins so 608 we were correct, 546 we were wrong

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# np.float64(0.5849056603773585)

# %%
#when we predicted win, team only won 47% of time

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Barcelona")

# %%
group
# Out:
#          date   time     comp         round  day venue result   gf   ga  \
# 0  2023-08-13  21:30  La Liga   Matchweek 1  Sun  Away      D  0.0  0.0
# 1  2023-08-20  19:30  La Liga   Matchweek 2  Sun  Home      W  2.0  0.0
# 2  2023-08-27  17:30  La Liga   Matchweek 3  Sun  Away      W  4.0  3.0
# 3  2023-09-03  21:00  La Liga   Matchweek 4  Sun  Away      W  2.0  1.0
# 4  2023-09-16  21:00  La Liga   Matchweek 5  Sat  Home      W  5.0  0.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 54 2018-04-29  20:45  La Liga  Matchweek 35  Sun  Away      W  4.0  2.0
# 55 2018-05-06  20:45  La Liga  Matchweek 36  Sun  Home      D  2.0  2.0
# 56 2018-05-09  20:00  La Liga  Matchweek 34  Wed  Home      W  5.0  1.0
# 57 2018-05-13  20:45  La Liga  Matchweek 37  Sun  Away      L  4.0  5.0
# 58 2018-05-20  20:45  La Liga  Matchweek 38  Sun  Home      W  1.0  0.0
#
#          opponent  ...   fk  pk  pkatt  season       team venue_code opp_code  \
# 0          Getafe  ...  1.0   0      0    2024  Barcelona          0       11
# 1           Cádiz  ...  2.0   0      0    2024  Barcelona          1        7
# 2      Villarreal  ...  0.0   0      0    2024  Barcelona          0       28
# 3         Osasuna  ...  0.0   1      1    2024  Barcelona          0       21
# 4           Betis  ...  2.0   0      0    2024  Barcelona          1        5
# ..            ...  ...  ...  ..    ...     ...        ...        ...      ...
# 54      La Coruña  ...  1.0   0      0    2023  Barcelona          0       15
# 55    Real Madrid  ...  1.0   0      0    2023  Barcelona          1       23
# 56     Villarreal  ...  0.0   0      0    2023  Barcelona          1       28
# 57        Levante  ...  1.0   1      1    2023  Barcelona          0       18
# 58  Real Sociedad  ...  1.0   0      0    2023  Barcelona          1       24
#
#    hour day_code  target
# 0    21        6       0
# 1    19        6       1
# 2    17        6       1
# 3    21        6       1
# 4    21        5       1
# ..  ...      ...     ...
# 54   20        6       1
# 55   20        6       0
# 56   20        2       1
# 57   20        6       0
# 58   20        6       1
#
# [456 rows x 33 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed = 'left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset = new_cols)
    #^deals with missing vals
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time     comp         round  day venue result   gf   ga  \
# 6  2017-09-16  16:15  La Liga   Matchweek 4  Sat  Away      W  2.0  1.0
# 7  2017-09-19  22:00  La Liga   Matchweek 5  Tue  Home      W  6.0  1.0
# 8  2017-09-23  20:45  La Liga   Matchweek 6  Sat  Away      W  3.0  0.0
# 10 2017-10-01  16:15  La Liga   Matchweek 7  Sun  Home      W  3.0  0.0
# 11 2017-10-14  20:45  La Liga   Matchweek 8  Sat  Away      D  1.0  1.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 52 2024-05-26  21:00  La Liga  Matchweek 38  Sun  Away      W  2.0  1.0
# 52 2024-05-26  21:00  La Liga  Matchweek 38  Sun  Away      W  2.0  1.0
# 52 2024-05-26  21:00  La Liga  Matchweek 38  Sun  Away      W  2.0  1.0
# 52 2024-05-26  21:00  La Liga  Matchweek 38  Sun  Away      W  2.0  1.0
# 52 2024-05-26  21:00  La Liga  Matchweek 38  Sun  Away      W  2.0  1.0
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 6            Getafe  ...         5       1    3.000000    0.000000  19.000000
# 7             Eibar  ...         1       1    3.000000    0.333333  16.333333
# 8            Girona  ...         5       1    4.333333    0.666667  12.333333
# 10       Las Palmas  ...         6       1    3.666667    0.666667   8.666667
# 11  Atlético Madrid  ...         5       0    4.000000    0.333333  13.666667
# ..              ...  ...       ...     ...         ...         ...        ...
# 52          Sevilla  ...         6       1    2.666667    0.333333  13.000000
# 52          Sevilla  ...         6       1    2.333333    0.666667  12.000000
# 52          Sevilla  ...         6       1    2.000000    1.000000  11.000000
# 52          Sevilla  ...         6       1    2.000000    1.000000  11.000000
# 52          Sevilla  ...         6       1    2.000000    1.000000  11.000000
#
#    sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 6     7.000000    17.600000   2.333333   0.000000       0.333333
# 7     8.000000    17.866667   1.666667   0.000000       0.333333
# 8     7.666667    17.466667   1.666667   0.333333       0.333333
# 10    6.333333    19.166667   1.333333   0.333333       0.333333
# 11    8.000000    17.466667   2.000000   0.333333       0.333333
# ..         ...          ...        ...        ...            ...
# 52    6.000000    15.833333   0.666667   0.000000       0.000000
# 52    6.000000    14.766667   0.333333   0.000000       0.000000
# 52    6.000000    13.700000   0.000000   0.000000       0.000000
# 52    6.000000    13.700000   0.000000   0.000000       0.000000
# 52    6.000000    13.700000   0.000000   0.000000       0.000000
#
# [453 rows x 41 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# C:\Users\Jason\AppData\Local\Temp\ipykernel_11512\4052147919.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                     date   time     comp         round  day venue result   gf  \
# team
# Alaves     3  2017-09-17  12:00  La Liga   Matchweek 4  Sun  Home      L  0.0
#            4  2017-09-20  21:00  La Liga   Matchweek 5  Wed  Away      L  0.0
#            5  2017-09-23  16:15  La Liga   Matchweek 6  Sat  Home      L  1.0
#            6  2017-09-30  18:30  La Liga   Matchweek 7  Sat  Away      W  2.0
#            7  2017-10-14  18:30  La Liga   Matchweek 8  Sat  Home      L  0.0
# ...                  ...    ...      ...           ...  ...   ...    ...  ...
# Villarreal 48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0
#            48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0
#            48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0
#            48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0
#            48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0
#
#                 ga       opponent  ...  day_code  target  gf_rolling  \
# team                               ...
# Alaves     3   3.0     Villarreal  ...         6       0    0.000000
#            4   1.0      La Coruña  ...         2       0    0.000000
#            5   2.0    Real Madrid  ...         5       0    0.000000
#            6   0.0        Levante  ...         5       1    0.333333
#            7   2.0  Real Sociedad  ...         5       0    1.000000
# ...            ...            ...  ...       ...     ...         ...
# Villarreal 48  1.0        Osasuna  ...         5       0    4.000000
#            48  1.0        Osasuna  ...         5       0    3.000000
#            48  1.0        Osasuna  ...         5       0    2.000000
#            48  1.0        Osasuna  ...         5       0    1.000000
#            48  1.0        Osasuna  ...         5       0    1.000000
#
#                ga_rolling sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Alaves     3     1.333333   8.000000    3.000000    20.066667   0.666667
#            4     2.000000  10.666667    2.333333    20.533333   1.000000
#            5     1.666667   9.666667    2.666667    20.200000   0.333333
#            6     2.000000  10.666667    2.666667    21.233333   0.666667
#            7     1.000000   8.000000    3.000000    17.633333   0.666667
# ...                   ...        ...         ...          ...        ...
# Villarreal 48    4.000000  21.000000    7.000000    15.600000   0.000000
#            48    3.000000  17.666667    5.666667    16.166667   0.000000
#            48    2.000000  14.333333    4.333333    16.733333   0.000000
#            48    1.000000  11.000000    3.000000    17.300000   0.000000
#            48    1.000000  11.000000    3.000000    17.300000   0.000000
#
#               pk_rolling  pkatt_rolling
# team
# Alaves     3         0.0       0.333333
#            4         0.0       0.000000
#            5         0.0       0.000000
#            6         0.0       0.000000
#            7         0.0       0.000000
# ...                  ...            ...
# Villarreal 48        0.0       0.000000
#            48        0.0       0.000000
#            48        0.0       0.000000
#            48        0.0       0.000000
#            48        0.0       0.000000
#
# [8457 rows x 41 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time     comp         round  day venue result   gf   ga  \
# 3  2017-09-17  12:00  La Liga   Matchweek 4  Sun  Home      L  0.0  3.0
# 4  2017-09-20  21:00  La Liga   Matchweek 5  Wed  Away      L  0.0  1.0
# 5  2017-09-23  16:15  La Liga   Matchweek 6  Sat  Home      L  1.0  2.0
# 6  2017-09-30  18:30  La Liga   Matchweek 7  Sat  Away      W  2.0  0.0
# 7  2017-10-14  18:30  La Liga   Matchweek 8  Sat  Home      L  0.0  2.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0  1.0
# 48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0  1.0
# 48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0  1.0
# 48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0  1.0
# 48 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0  1.0
#
#          opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 3      Villarreal  ...         6       0    0.000000    1.333333   8.000000
# 4       La Coruña  ...         2       0    0.000000    2.000000  10.666667
# 5     Real Madrid  ...         5       0    0.000000    1.666667   9.666667
# 6         Levante  ...         5       1    0.333333    2.000000  10.666667
# 7   Real Sociedad  ...         5       0    1.000000    1.000000   8.000000
# ..            ...  ...       ...     ...         ...         ...        ...
# 48        Osasuna  ...         5       0    4.000000    4.000000  21.000000
# 48        Osasuna  ...         5       0    3.000000    3.000000  17.666667
# 48        Osasuna  ...         5       0    2.000000    2.000000  14.333333
# 48        Osasuna  ...         5       0    1.000000    1.000000  11.000000
# 48        Osasuna  ...         5       0    1.000000    1.000000  11.000000
#
#    sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 3     3.000000    20.066667   0.666667        0.0       0.333333
# 4     2.333333    20.533333   1.000000        0.0       0.000000
# 5     2.666667    20.200000   0.333333        0.0       0.000000
# 6     2.666667    21.233333   0.666667        0.0       0.000000
# 7     3.000000    17.633333   0.666667        0.0       0.000000
# ..         ...          ...        ...        ...            ...
# 48    7.000000    15.600000   0.000000        0.0       0.000000
# 48    5.666667    16.166667   0.000000        0.0       0.000000
# 48    4.333333    16.733333   0.000000        0.0       0.000000
# 48    3.000000    17.300000   0.000000        0.0       0.000000
# 48    3.000000    17.300000   0.000000        0.0       0.000000
#
# [8457 rows x 41 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time     comp         round  day venue result   gf   ga  \
# 0    2017-09-17  12:00  La Liga   Matchweek 4  Sun  Home      L  0.0  3.0
# 1    2017-09-20  21:00  La Liga   Matchweek 5  Wed  Away      L  0.0  1.0
# 2    2017-09-23  16:15  La Liga   Matchweek 6  Sat  Home      L  1.0  2.0
# 3    2017-09-30  18:30  La Liga   Matchweek 7  Sat  Away      W  2.0  0.0
# 4    2017-10-14  18:30  La Liga   Matchweek 8  Sat  Home      L  0.0  2.0
# ...         ...    ...      ...           ...  ...   ...    ...  ...  ...
# 8452 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0  1.0
# 8453 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0  1.0
# 8454 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0  1.0
# 8455 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0  1.0
# 8456 2024-05-25  14:00  La Liga  Matchweek 38  Sat  Away      D  1.0  1.0
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 0        Villarreal  ...         6       0    0.000000    1.333333   8.000000
# 1         La Coruña  ...         2       0    0.000000    2.000000  10.666667
# 2       Real Madrid  ...         5       0    0.000000    1.666667   9.666667
# 3           Levante  ...         5       1    0.333333    2.000000  10.666667
# 4     Real Sociedad  ...         5       0    1.000000    1.000000   8.000000
# ...             ...  ...       ...     ...         ...         ...        ...
# 8452        Osasuna  ...         5       0    4.000000    4.000000  21.000000
# 8453        Osasuna  ...         5       0    3.000000    3.000000  17.666667
# 8454        Osasuna  ...         5       0    2.000000    2.000000  14.333333
# 8455        Osasuna  ...         5       0    1.000000    1.000000  11.000000
# 8456        Osasuna  ...         5       0    1.000000    1.000000  11.000000
#
#      sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 0       3.000000    20.066667   0.666667        0.0       0.333333
# 1       2.333333    20.533333   1.000000        0.0       0.000000
# 2       2.666667    20.200000   0.333333        0.0       0.000000
# 3       2.666667    21.233333   0.666667        0.0       0.000000
# 4       3.000000    17.633333   0.666667        0.0       0.000000
# ...          ...          ...        ...        ...            ...
# 8452    7.000000    15.600000   0.000000        0.0       0.000000
# 8453    5.666667    16.166667   0.000000        0.0       0.000000
# 8454    4.333333    16.733333   0.000000        0.0       0.000000
# 8455    3.000000    17.300000   0.000000        0.0       0.000000
# 8456    3.000000    17.300000   0.000000        0.0       0.000000
#
# [8457 rows x 41 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] >= '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual = test["target"], prediction = preds), index = test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# np.float64(0.6213592233009708)

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index = True, right_index = True)

# %%
class MissingDict(dict):
    __missing__  = lambda self, key : key

map_values = {
}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(map_values)

# %%
merged = combined.merge(combined, left_on = ["date", "new_team"], right_on = ["date", "opponent"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[493], line 1
# ----> 1 merged = combined.merge(combined, left_on = ["date", "new_team"], right_on = ["date", "opponent"])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)
#   10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
#   10830     from pandas.core.reshape.merge import merge
# > 10832     return merge(
#   10833         self,
#   10834         right,
#   10835         how=how,
#   10836         on=on,
#   10837         left_on=left_on,
#   10838         right_on=right_on,
#   10839         left_index=left_index,
#   10840         right_index=right_index,
#   10841         sort=sort,
#   10842         suffixes=suffixes,
#   10843         copy=copy,
#   10844         indicator=indicator,
#   10845         validate=validate,
#   10846     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)
#     167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
#     181         indicator=indicator,
#     182         validate=validate,
#     183     )
#     184     return op.get_result(copy=copy)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:807, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     803 self._validate_tolerance(self.left_join_keys)
#     805 # validate the merge keys dtypes. We may need to coerce
#     806 # to avoid incompatible dtypes
# --> 807 self._maybe_coerce_merge_keys()
#     809 # If argument passed to validate,
#     810 # check if columns specified as unique
#     811 # are in fact unique.
#     812 if validate is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:1508, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1502     # unless we are merging non-string-like with string-like
#    1503     elif (
#    1504         inferred_left in string_types and inferred_right not in string_types
#    1505     ) or (
#    1506         inferred_right in string_types and inferred_left not in string_types
#    1507     ):
# -> 1508         raise ValueError(msg)
#    1510 # datetimelikes must match exactly
#    1511 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on float64 and object columns for key 'new_team'. If you wish to proceed you should use pd.concat

# %%
merged
# Out:
#       actual_x  prediction_x       date         team_x       opponent_x  \
# 0            1             0 2023-01-06     Celta Vigo            Elche
# 1            0             1 2023-01-13     Celta Vigo       Villarreal
# 2            0             0 2023-01-20     Celta Vigo         Mallorca
# 3            1             1 2023-01-29     Celta Vigo    Athletic Club
# 4            1             0 2023-02-04     Celta Vigo            Betis
# ...        ...           ...        ...            ...              ...
# 5459         0             0 2024-05-25  Real Sociedad  Atlético Madrid
# 5460         0             0 2024-05-25  Real Sociedad  Atlético Madrid
# 5461         0             0 2024-05-25  Real Sociedad  Atlético Madrid
# 5462         0             0 2024-05-25  Real Sociedad  Atlético Madrid
# 5463         0             0 2024-05-25  Real Sociedad  Atlético Madrid
#
#      result_x     new_team_x  actual_y  prediction_y           team_y  \
# 0           W     Celta Vigo         0             0            Elche
# 1           D     Celta Vigo         0             0       Villarreal
# 2           L     Celta Vigo         1             0         Mallorca
# 3           W     Celta Vigo         0             0    Athletic Club
# 4           W     Celta Vigo         0             1       Real Betis
# ...       ...            ...       ...           ...              ...
# 5459        L  Real Sociedad         1             0  Atletico Madrid
# 5460        L  Real Sociedad         1             0  Atletico Madrid
# 5461        L  Real Sociedad         1             0  Atletico Madrid
# 5462        L  Real Sociedad         1             0  Atletico Madrid
# 5463        L  Real Sociedad         1             0  Atletico Madrid
#
#          opponent_y result_y new_team_y
# 0        Celta Vigo        L        NaN
# 1        Celta Vigo        D        NaN
# 2        Celta Vigo        W        NaN
# 3        Celta Vigo        L        NaN
# 4        Celta Vigo        L        NaN
# ...             ...      ...        ...
# 5459  Real Sociedad        W        NaN
# 5460  Real Sociedad        W        NaN
# 5461  Real Sociedad        W        NaN
# 5462  Real Sociedad        W        NaN
# 5463  Real Sociedad        W        NaN
#
# [5464 rows x 13 columns]

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    965
# 0    577
# Name: count, dtype: int64

# %%
965 + 577
# Out:
# 1542

# %%
965 / 1542
# Out:
# 0.625810635538262

# %%
matches.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'opp formation', 'referee', 'match report', 'notes', 'sh', 'sot',
#        'dist', 'fk', 'pk', 'pkatt', 'season', 'team', 'venue_code', 'opp_code',
#        'hour', 'day_code', 'target'],
#       dtype='object')
